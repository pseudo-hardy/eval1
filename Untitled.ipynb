# %%
records = [[]]
# FINAL
def add_book(inventory, i):
    title = input("Enter the title of the book")
    author = input("Enter author")
    genre = input("Enter genre")
    ISBN = int(input("Enter ISBN"))
    availability = True
    inventory["title"]=title
    inventory["author"]=author
    inventory["ISBN"]=ISBN
    inventory["genre"]=genre
    inventory["availability"]=True
    records[i]= inventory
    i = i+1

    # FINAL

def update_book_details(records):
    book = int(input("Enter ISBN of the book to search"))
    for i in records:
        if i["ISBN"] == book:
            ty = input("do you wish to update the title of the book? 0 for no 1 for yes")
            if(ty == '1'):
                title = input("Enter the title of the book")
                i["title"] = title
                ty = input("do you wish to update the author of the book? 0 for no 1 for yes")
            if(ty == '1'):
                author = input("Enter author")
                i["author"] = author
            ty = input("do you wish to update the status of the book? 0 for no 1 for yes")
            if(ty == '1'):
                if i["availability"] == '0':
                    i["availability"] = '1'
                else:
                    i["availability"] = '0'
        
# FINAL
def search_by_isbn(records):
    isbn = int(input("Enter isbn of the book to search"))
    for i in records:
        if(i["ISBN"] == isbn):
                print(i)

def generate_genre_report(records):
    for i in records:
        if i["availability"] == '1':
            print(i["title"])
    
inventory = dict();
# inventory["title"] ="Book1"
# inventory["author"] = "James"
# inventory["genre"] ="Action"
# inventory["availability"] = True
# inventory["ISBN"] = 1
i = 0
add_book(inventory, i)
add_book(inventory, i)
print(records)
search_by_isbn(records)
update_book_details(records)
search_by_isbn(records)
generate_genre_report(records)
# print(records)
